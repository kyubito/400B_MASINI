# %%
# import modules
import numpy as np
import astropy.units as u
from astropy.constants import G

# import plotting modules
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# my modules
from ReadFile import Read
from CenterOfMass2 import CenterOfMass
from MassProfile import MassProfile
from OrbitCOM import OrbitCOM

# %%
#hw 6 good
#not all snapchot useful about 7 snap

#HW5 Mass Profile then change to a density profile by divinding by radius^3 cube (Mass/Kpc3)
#fit Hernquist profile by massprofile

#lecture 4 for DM density profile

#LowRes files

# %%
# Create MassProfile Objects for each Galaxy

M33 = MassProfile("M33",0)
#ScaleM33 = 25
#MtotM33 = 0.187e12

# %%
# Plot the Density Profile for M33.


fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)

# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create a spherical volume
V = ((4*np.pi*(R**3))/3)

# Plot mass enclosed for Halo 
plt.semilogy(R,M33.MassEnclosed(1,R)/V, color='blue',linestyle="--", linewidth=5)#, label='Halo')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'(Log Density Enclosed (M$_\odot$/V))', fontsize=22)

#set axis limits
#plt.ylim(1e9,1e12)

#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


#add figure text
plt.figtext(0.25, 0.83, 'M33 halo Density Profile at snap 0', fontsize=22)

# Save to a file
#ax.set_rasterized(True)
#plt.savefig('MassProfile_M33.eps', rasterized=True, dpi=350)
# Out:
# Text(0.25, 0.83, 'M33 halo Density Profile at snap 0')

# %%
M33_10 = MassProfile("M33",10)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)

# Plot mass enclosed for Halo 
plt.semilogy(R,M33.MassEnclosed(1,R)/V, color='blue',linestyle="--", linewidth=5)#, label='Halo')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'(Log Density Enclosed (M$_\odot$/$R^3$))', fontsize=22)


#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size

#add figure text
plt.figtext(0.25, 0.83, 'M33 halo Density Mass Profile snap 10', fontsize=22)
# Out:
# Text(0.25, 0.83, 'M33 halo Density Mass Profile snap 10')

# %%
#Plot disk density profile at snap 0

M33_0 = MassProfile("M33",0)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)


# for Disk
plt.semilogy(R,M33_0.MassEnclosed(2,R)/V, color='red', linestyle=":", linewidth=3, label='Disk')



# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'(Log Density Enclosed (M$_\odot$/V))', fontsize=22)

#set axis limits
#plt.ylim(1e9,1e12)

#adjust tick label font size
#label_size = 22
#matplotlib.rcParams['xtick.labelsize'] = label_size 
#matplotlib.rcParams['ytick.labelsize'] = label_size

# add a legend with some customizations.
#legend = ax.legend(loc='lower right',fontsize='x-large')

#add figure text
plt.figtext(0.25, 0.83, 'M33 Disk Density Mass Profile snap 0', fontsize=22)


# Save to a file
#ax.set_rasterized(True)
#plt.savefig('MassProfile_M33.eps', rasterized=True, dpi=350)
# Out:
# Text(0.25, 0.83, 'M33 Disk Density Mass Profile snap 0')

# %%
# Disk density profile at snap 10

M33_10 = MassProfile("M33",10)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)


# for Disk
plt.semilogy(R,M33_10.MassEnclosed(2,R)/V, color='red', linestyle=":", linewidth=3, label='Disk')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'(Log Density Enclosed (M$_\odot$/V))', fontsize=22)

#set axis limits
#plt.ylim(1e9,1e12)

#adjust tick label font size
#label_size = 22
#matplotlib.rcParams['xtick.labelsize'] = label_size 
#matplotlib.rcParams['ytick.labelsize'] = label_size

# add a legend with some customizations.
#legend = ax.legend(loc='lower right',fontsize='x-large')

#add figure text
plt.figtext(0.25, 0.83, 'M33 Disk Density Mass Profile snap 10', fontsize=22)


# Save to a file
#ax.set_rasterized(True)
#plt.savefig('MassProfile_M33.eps', rasterized=True, dpi=350)
# Out:
# Text(0.25, 0.83, 'M33 Disk Density Mass Profile snap 10')

# %%
# Plot Halo density profile from snap 0-10

# %%
M33_0 = MassProfile("M33",0)
M33_1 = MassProfile("M33",1)
M33_2 = MassProfile("M33",2)
M33_3 = MassProfile("M33",3)
M33_4 = MassProfile("M33",4)
M33_5 = MassProfile("M33",5)
M33_6 = MassProfile("M33",6)
M33_7 = MassProfile("M33",7)
M33_8 = MassProfile("M33",8)
M33_9 = MassProfile("M33",9)
M33_10 = MassProfile("M33",10)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)


# Halo Snap 0
plt.semilogy(R,M33_0.MassEnclosed(1,R)/V, color='blue', linewidth=5, label='Snap 0')
# Halo Snap 1
plt.semilogy(R,M33_1.MassEnclosed(1,R)/V, color='red', linestyle=":", linewidth=3, label='Snap 1')
# Halo Snap 2
plt.semilogy(R,M33_2.MassEnclosed(1,R)/V, color='green', linestyle="--",linewidth=3, label='Snap 2')
# Halo snap 3
plt.semilogy(R,M33_3.MassEnclosed(1,R)/V, color='black', linestyle="--",linewidth=5, label='Snap 3')
# Halo Snap 4
plt.semilogy(R,M33_4.MassEnclosed(1,R)/V, color='magenta',linestyle="--",linewidth=5, label='Snap 4')
# Halo Snap 5
plt.semilogy(R,M33_5.MassEnclosed(1,R)/V, color='cyan', linewidth=5, label='Snap 5')
# Halo Snap 6
plt.semilogy(R,M33_6.MassEnclosed(1,R)/V, color='yellow', linestyle=":", linewidth=3, label='Snap 6')
# Halo Snap 7
plt.semilogy(R,M33_7.MassEnclosed(1,R)/V, color='salmon', linestyle="--",linewidth=3, label='Snap 7')
# Halo snap 8
plt.semilogy(R,M33_8.MassEnclosed(1,R)/V, color='orange', linestyle="--",linewidth=5, label='Snap 8')
# Halo Snap 9
plt.semilogy(R,M33_9.MassEnclosed(1,R)/V, color='pink',linestyle="--",linewidth=5, label='Snap 9')
# Halo Snap 10
plt.semilogy(R,M33_10.MassEnclosed(1,R)/V, color='silver',linestyle="--",linewidth=5, label='Snap 10')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'Log(Mass Enclosed (M$_\odot$/V)', fontsize=22)


#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# add a legend with some customizations.
legend = ax.legend(loc='lower right',fontsize='x-large')

#add figure text
plt.figtext(0.25, 0.83, 'M33 Halo Density profile snap(0-10)', fontsize=22)
# Out:
# Text(0.25, 0.83, 'M33 Halo Density profile snap(0-10)')

# %%
# Halo Density profile snap 0-800

# %%
M33_0 = MassProfile("M33",0)
M33_200 = MassProfile("M33",200)
M33_400 = MassProfile("M33",400)
M33_600 = MassProfile("M33",600)
M33_800 = MassProfile("M33",800)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)


# Halo Snap 0
plt.semilogy(R,M33_0.MassEnclosed(1,R)/V, color='blue', linewidth=5, label='Snap 0')

# Halo Snap 200
plt.semilogy(R,M33_200.MassEnclosed(1,R)/V, color='red', linestyle=":", linewidth=3, label='Snap 200')

# Halo Snap 400
plt.semilogy(R,M33_400.MassEnclosed(1,R)/V, color='green', linestyle="--",linewidth=3, label='Snap 400')

# Halo snap 600
plt.semilogy(R,M33_600.MassEnclosed(1,R)/V, color='black', linestyle="--",linewidth=5, label='Snap 600')

# Halo Snap 800
plt.semilogy(R,M33_800.MassEnclosed(1,R)/V, color='magenta',linestyle="--",linewidth=5, label='Snap 800')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'Log(Mass Enclosed (M$_\odot$/V)', fontsize=22)


#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# add a legend with some customizations.
legend = ax.legend(loc='lower right',fontsize='x-large')

#add figure text
plt.figtext(0.25, 0.83, 'M33 Halo Density profile, snap(0-800)', fontsize=22)
# Out:
# Text(0.25, 0.83, 'M33 Halo Density profile, snap(0-800)')

# %%
# Halo Density profile snap 600-700

# %%
# Plot the Mass Profile for the MW.
####################################
M33_600 = MassProfile("M33",600)
M33_620 = MassProfile("M33",620)
M33_640 = MassProfile("M33",640)
M33_660 = MassProfile("M33",660)
M33_680 = MassProfile("M33",680)
M33_700 = MassProfile("M33",700)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)


# Halo Snap 600
plt.semilogy(R,M33_600.MassEnclosed(1,R)/V, color='blue', linewidth=5, label='Snap 600')

# Halo Snap 620
plt.semilogy(R,M33_620.MassEnclosed(1,R)/V, color='red', linestyle=":", linewidth=3, label='Snap 620')

# Halo Snap 640
plt.semilogy(R,M33_640.MassEnclosed(1,R)/V, color='green', linestyle="--",linewidth=3, label='Snap 640')

# Halo snap 660
plt.semilogy(R,M33_660.MassEnclosed(1,R)/V, color='black', linestyle="--",linewidth=5, label='Snap 660')

# Halo Snap 680
plt.semilogy(R,M33_680.MassEnclosed(1,R)/V, color='magenta',linestyle="--",linewidth=5, label='Snap 680')

# Halo Snap 700
plt.semilogy(R,M33_700.MassEnclosed(1,R)/V, color='salmon',linestyle="--",linewidth=5, label='Snap 700')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'Log(Mass Enclosed (M$_\odot$/V)', fontsize=22)


#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# add a legend with some customizations.
legend = ax.legend(loc='lower right',fontsize='x-large')

#add figure text
plt.figtext(0.19, 0.89, 'M33 Halo Density profile snap(600-700)', fontsize=22)
# Out:
# Text(0.19, 0.89, 'M33 Halo Density profile snap(600-700)')

# %%
#Now we are looking at disk density profile snap 0-10

# %%
# Disk density profile using snapshot from 0 to 10
M33_0 = MassProfile("M33",0)
M33_1 = MassProfile("M33",1)
M33_2 = MassProfile("M33",2)
M33_3 = MassProfile("M33",3)
M33_4 = MassProfile("M33",4)
M33_5 = MassProfile("M33",5)
M33_6 = MassProfile("M33",6)
M33_7 = MassProfile("M33",7)
M33_8 = MassProfile("M33",8)
M33_9 = MassProfile("M33",9)
M33_10 = MassProfile("M33",10)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)


# Halo Snap 0
plt.semilogy(R,M33_0.MassEnclosed(2,R)/V, color='blue', linewidth=5, label='Snap 0')
# Halo Snap 1
plt.semilogy(R,M33_1.MassEnclosed(2,R)/V, color='red', linestyle=":", linewidth=3, label='Snap 1')
# Halo Snap 2
plt.semilogy(R,M33_2.MassEnclosed(2,R)/V, color='green', linestyle="--",linewidth=3, label='Snap 2')
# Halo snap 3
plt.semilogy(R,M33_3.MassEnclosed(2,R)/V, color='black', linestyle="--",linewidth=5, label='Snap 3')
# Halo Snap 4
plt.semilogy(R,M33_4.MassEnclosed(2,R)/V, color='magenta',linestyle="--",linewidth=5, label='Snap 4')
# Halo Snap 5
plt.semilogy(R,M33_5.MassEnclosed(2,R)/V, color='cyan', linewidth=5, label='Snap 5')
# Halo Snap 6
plt.semilogy(R,M33_6.MassEnclosed(2,R)/V, color='yellow', linestyle=":", linewidth=3, label='Snap 6')
# Halo Snap 7
plt.semilogy(R,M33_7.MassEnclosed(2,R)/V, color='salmon', linestyle="--",linewidth=3, label='Snap 7')
# Halo snap 8
plt.semilogy(R,M33_8.MassEnclosed(2,R)/V, color='orange', linestyle="--",linewidth=5, label='Snap 8')
# Halo Snap 9
plt.semilogy(R,M33_9.MassEnclosed(2,R)/V, color='pink',linestyle="--",linewidth=5, label='Snap 9')
# Halo Snap 10
plt.semilogy(R,M33_10.MassEnclosed(2,R)/V, color='silver',linestyle="--",linewidth=5, label='Snap 10')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'Log(Mass Enclosed (M$_\odot$/V)', fontsize=22)


#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# add a legend with some customizations.
legend = ax.legend(loc='lower right',fontsize='x-large')

#add figure text
plt.figtext(0.25, 0.83, 'M33 Disk Density profile snap(0-10)', fontsize=22)
# Out:
# Text(0.25, 0.83, 'M33 Disk Density profile snap(0-10)')

# %%
# Disk density profile using snapshot from 0 to 800

# %%
M33_0 = MassProfile("M33",0)
M33_200 = MassProfile("M33",200)
M33_400 = MassProfile("M33",400)
M33_600 = MassProfile("M33",600)
M33_800 = MassProfile("M33",800)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)


# Halo Snap 0
plt.semilogy(R,M33_0.MassEnclosed(2,R)/V, color='blue', linewidth=5, label='Snap 0')

# Halo Snap 200
plt.semilogy(R,M33_200.MassEnclosed(2,R)/V, color='red', linestyle=":", linewidth=3, label='Snap 200')

# Halo Snap 400
plt.semilogy(R,M33_400.MassEnclosed(2,R)/V, color='green', linestyle="--",linewidth=3, label='Snap 400')

# Halo snap 600
plt.semilogy(R,M33_600.MassEnclosed(2,R)/V, color='black', linestyle="--",linewidth=5, label='Snap 600')

# Halo Snap 800
plt.semilogy(R,M33_800.MassEnclosed(2,R)/V, color='magenta',linestyle="--",linewidth=5, label='Snap 800')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'Log(Mass Enclosed (M$_\odot$/V)', fontsize=22)


#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# add a legend with some customizations.
legend = ax.legend(loc='lower right',fontsize='x-large')

#add figure text
plt.figtext(0.25, 0.83, 'M33 Disk Density profile, snap(0-800)', fontsize=22)
# Out:
# Text(0.25, 0.83, 'M33 Disk Density profile, snap(0-800)')

# %%
# Disk density profile using snapshot from 600 to 700

# %%
# Plot the Mass Profile for the MW.
####################################
M33_600 = MassProfile("M33",600)
M33_620 = MassProfile("M33",620)
M33_640 = MassProfile("M33",640)
M33_660 = MassProfile("M33",660)
M33_680 = MassProfile("M33",680)
M33_700 = MassProfile("M33",700)

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
    
# Create an array to store Radius, from 0-30 kpc
# intervals of 0.5 kpc
R = np.arange(0.1,31,0.5)

#Create the volume of the sphere containing the matter in a given radius
V = ((4*np.pi*(R**3))/3)


# Halo Snap 600
plt.semilogy(R,M33_600.MassEnclosed(2,R)/V, color='blue', linewidth=5, label='Snap 600')

# Halo Snap 620
plt.semilogy(R,M33_620.MassEnclosed(2,R)/V, color='red', linestyle=":", linewidth=3, label='Snap 620')

# Halo Snap 640
plt.semilogy(R,M33_640.MassEnclosed(2,R)/V, color='green', linestyle="--",linewidth=3, label='Snap 640')

# Halo snap 660
plt.semilogy(R,M33_660.MassEnclosed(2,R)/V, color='black', linestyle="--",linewidth=5, label='Snap 660')

# Halo Snap 680
plt.semilogy(R,M33_680.MassEnclosed(2,R)/V, color='magenta',linestyle="--",linewidth=5, label='Snap 680')

# Halo Snap 700
plt.semilogy(R,M33_700.MassEnclosed(2,R)/V, color='salmon',linestyle="--",linewidth=5, label='Snap 700')


# Add axis labels
plt.xlabel('Radius (kpc)', fontsize=22)
plt.ylabel(r'Log(Mass Enclosed (M$_\odot$/V)', fontsize=22)


#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# add a legend with some customizations.
legend = ax.legend(loc='lower right',fontsize='x-large')

#add figure text
plt.figtext(0.19, 0.89, 'M33 Disk Density profile snap(600-700)', fontsize=22)
# Out:
# Text(0.19, 0.89, 'M33 Disk Density profile snap(600-700)')

# %%
# What happen around 600 ?

# Need to look at Hernquist profile
